# %%
import os
import re

# Define paths (edit if needed)
spam_dirs = ["./spam", "./spam_2"]  # Set to your actual relative or absolute paths

# Keyword heuristics for categories
CATEGORY_KEYWORDS = {
  "Phishing": [
        "password", "verify", "account", "login", "bank", "confirm", "update", "ssn", "secure",
        "security alert", "reset", "your information", "identity", "limited time", "reactivate",
        "unusual activity", "locked", "access", "credentials", "statement", "protection", "atm",
        "security notice", "validate", "immediately", "confirm your", "click here to", "log in",
        "suspend", "alert", "dear customer", "customer service", "your paypal", "your amazon",
        "verify your email", "we detected", "compromised", "security check"
    ],    "Impersonation": [
        "ceo", "urgent", "wire transfer", "invoice", "payment", "request", "manager", "attention",
        "director", "immediate", "funds", "action required", "process payment", "approve", "remit",
        "from the desk of", "please reply", "staff", "employee", "vendor", "remittance", "outstanding",
        "authorize", "executive", "human resources", "payroll", "boss", "confidential", "financial dept",
        "hr department", "final notice", "settlement", "your supervisor", "tax"
    ],
   "Promotional Ads": [
        "free", "offer", "buy now", "winner", "discount", "click here", "order now", "limited time",
        "sale", "deal", "prize", "promotion", "gift", "risk-free", "guaranteed", "act now", "save big",
        "cheap", "lowest price", "win", "selected", "cash", "bonus", "opportunity", "get paid",
        "amazing", "exclusive", "luxury", "vacation", "bargain", "unsubscribe", "satisfaction", "no cost",
        "trial", "fast cash", "zero risk", "hot deal", "special offer"
    ]
}

# %%
def classify_spam(text):
    text_lc = text.lower()
    for category, keywords in CATEGORY_KEYWORDS.items():
        for kw in keywords:
            if kw in text_lc:
                return category
    return "Other"

# Gather results
results = {"Phishing": [], "Impersonation": [], "Promotional Ads": [], "Other": []}

# Read spam files
for folder in spam_dirs:
    for fname in os.listdir(folder):
        fpath = os.path.join(folder, fname)
        try:
            with open(fpath, encoding="latin1") as f:
                content = f.read()
                # For classification, you can combine subject+body if you extract subject
                results[classify_spam(content)].append(fname)
        except Exception as e:
            print(f"Could not read {fname}: {e}")

# %%
# Print summary
for category, files in results.items():
    print(f"{category}: {len(files)} emails")
    # Optional: print sample emails
    for sample in files[:3]:
        print(f"  - {sample}")
# Out:
# Phishing: 898 emails
#   - 00278.b62c5fc23a2f87760696cb9fa51f073c
#   - 00279.1d58a13e343c1e53aca2ed2121a3f815
# Promotional Ads: 626 emails
#   - 00322.7d39d31fb7aad32c15dff84c14019b8c
#   - 00328.73c1a9f83d3b1247522c26eb6d74c215
# Other: 95 emails
#   - 00010.445affef4c70feec58f9198cfbc22997
#   - 00074.51aab41b27a9ba7736803318a2e4c8de

# %%
# Output to txt file for your report
with open("spam_categories_summary.txt", "w") as out:
    for category, files in results.items():
        out.write(f"\n{category} ({len(files)} emails):\n")
        for fname in files:  # Only sample 10 per category
            out.write(f"  - {fname}\n")
print("Summary saved to spam_categories_summary.txt")
# Out:
# Summary saved to spam_categories_summary.txt

# %%
import os
import shutil

CATEGORY_FOLDER_MAP = {
    "Phishing": "phising", 
    "Promotional Ads": "Promotional Ads"
}

spam_dirs = ["./spam", "./spam_2"]

# Move up to 30 files per category
for category, files in results.items():
    folder_name = CATEGORY_FOLDER_MAP.get(category)
    if not folder_name:
        continue  # Skip categories with no folder

    # Only move up to 30
    for fname in files[:40]:
        found = False
        # Search both spam folders for the file
        for src_dir in spam_dirs:
            src_path = os.path.join(src_dir, fname)
            if os.path.exists(src_path):
                dst_path = os.path.join(folder_name, fname)
                shutil.move(src_path, dst_path)
                print(f"Moved {fname} to {folder_name}")
                found = True
                break
        if not found:
            print(f"{fname} not found in spam folders!")

print("Done moving files.")
# Out:
# Moved 00278.b62c5fc23a2f87760696cb9fa51f073c to phising
# Moved 00279.1d58a13e343c1e53aca2ed2121a3f815 to phising
# Moved 00280.026da2bd191f11081b8d8428134b0c66 to phising
# Moved 00282.0e230e05877f40a522bfb93aa3e314f3 to phising
# Moved 00283.e8e42ee52f919afd2a453983f1256b1d to phising
# Moved 00285.8a06c91fcdf4a1ae8ca928f3ef3feecb to phising
# Moved 00286.efd0b8f0c9c779b7a0ad93505c9b0bae to phising
# Moved 00287.b0495a4dbdff36654c3b3ee2f92bdbf3 to phising
# Moved 00289.61a681a72c71512f115ad65033acc7c9 to phising
# Moved 00290.eb053a191b7509a9399aa16717630414 to phising
# Moved 00291.7aa227e74e89bdd529a3875459d0d5a2 to phising
# Moved 00292.dbf78a2aaa230d288eb80ab843804252 to phising
# Moved 00294.df27a988d82cc82296e33e6d727ac47e to phising
# Moved 00301.68fe7955b96d085360ca916289e8e716 to phising
# Moved 00302.544366fa4cd0f5d210dd8443a1c2c95a to phising
# Moved 00304.ed5fbfc3e6f2be662f29f43f172a1fb3 to phising
# Moved 00305.f80c21904d6d4f6facd036450a588b0d to phising
# Moved 00307.7ed50c6d80c6e37c8cc1b132f4a19e4d to phising
# Moved 00310.3f652995aadb0bf696dd10c89ce30afc to phising
# Moved 00312.75c839d7d4f6da9e860a11b617904fb5 to phising
# Moved 00315.0ee82a2e087ffcf6efbd30b36499ead6 to phising
# Moved 00316.311d11f764c6e452b2f0208b53b94ea2 to phising
# Moved 00319.a99dff9c010e00ec182ed5701556d330 to phising
# Moved 00323.9e36bf05304c99f2133a4c03c49533a9 to phising
# Moved 00324.6f320a8c6b5f8e4bc47d475b3d4e86ef to phising
# Moved 00325.58d1a52f435030dc38568bc12a3d76a2 to phising
# Moved 00326.5ec68244bb085cb140deb79563abd7b3 to phising
# Moved 00327.7f21bc8575786a0e00341a6407b9f286 to phising
# Moved 00330.c5f7346dec1e6fe6ed324d8e78a2b46e to phising
# Moved 00331.a61788d316e7393c8bbf8ee19b24c713 to phising
# Moved 00332.580b62752adefb845db173e375271cb5 to phising
# Moved 00333.4bb36a535cb3d738f30f985f1e10a786 to phising
# Moved 00334.a1038f98abb76b403d068afb57bfb290 to phising
# Moved 00335.f71c6e9b23487811a44e6aeaa50e73a5 to phising
# Moved 00341.99b463b92346291f5848137f4a253966 to phising
# Moved 00346.1ae83883f566cdf6ff18958a33a215b3 to phising
# Moved 00347.0958e79c14164f0f902d863f41156c0b to phising
# Moved 00349.dd7982f40576ff4897c18efc813e38bf to phising
# Moved 00353.464ef65be6651440e15675faeb15a7ca to phising
# Moved 00354.dca4b8984863a76ffd01a33888498288 to phising
# Moved 00322.7d39d31fb7aad32c15dff84c14019b8c to Promotional Ads
# Moved 00328.73c1a9f83d3b1247522c26eb6d74c215 to Promotional Ads
# Moved 00337.813498483bc80a24c002e6e7e8e0f2cb to Promotional Ads
# Moved 00339.16bd110d8aa11e7d9398287c27b1b389 to Promotional Ads
# Moved 00342.0dab365fab3be83284b08ac5783335da to Promotional Ads
# Moved 00343.37d895b3a54847548875136ad6b0192d to Promotional Ads
# Moved 00344.17882edad13c2c761e6d8d99eef5a346 to Promotional Ads
# Moved 00345.613b3c2aeac033eebb379c91b8ce9fba to Promotional Ads
# Moved 00348.1948d1e6b724e8abf4b8f0fc024ac627 to Promotional Ads
# Moved 00350.c2658f17a328efdf045b38ab38db472f to Promotional Ads
# Moved 00351.fd1b8a6cd42e81125fb38c2660cd9317 to Promotional Ads
# Moved 00352.19a8ba03f566612e0b9e124609d9dbd0 to Promotional Ads
# Moved 00355.e10c2eba9316a09e612e6675ce339d5e to Promotional Ads
# Moved 00364.11dba84b95e0471927d1ebc8ff0017ef to Promotional Ads
# Moved 00365.da6795d02b44e4d5e168d62718f3e7c9 to Promotional Ads
# Moved 00366.f0bfcc3c84da11ae1154c6c593362f69 to Promotional Ads
# Moved 00368.2c1ab4bc7f408e0fcb22dca9b2d5a113 to Promotional Ads
# Moved 00371.3bc80f63aa7c64a56eb77fc82ce22e7f to Promotional Ads
# Moved 00374.8942e17f10389fe620e1e96cba52c9aa to Promotional Ads
# Moved 00376.f4ed5f002f9b6b320a67f1da9cacbe72 to Promotional Ads
# Moved 00379.f04dedf09dce65a80fbe1fd831abefd0 to Promotional Ads
# Moved 00383.1aa9a8211d1de540d6e3852e230e5a9d to Promotional Ads
# Moved 00386.6074f269f0bd1aec1546f9e654e8fcfe to Promotional Ads
# Moved 00387.8562ea27520ea0fa6030679792f2fb72 to Promotional Ads
# Moved 00391.e2c76e9dc5ef65b90275138f73eb475b to Promotional Ads
# Moved 00393.13d4d84cb98ea19954f895c629520bf8 to Promotional Ads
# Moved 00394.cca39f925676ecca947eaed2b600fe70 to Promotional Ads
# Moved 00399.cd1239166aa4d43f7c3127c3b48b3f18 to Promotional Ads
# Moved 00400.cc74b7994a7282f32ee2a3b7e3634d31 to Promotional Ads
# Moved 00401.309e29417819ce39d8599047d50933cc to Promotional Ads
# Moved 00403.46d0face754b6bb7dce8b3ea560f75fb to Promotional Ads
# Moved 00404.b4bbecbee92f735a845f589582e7695d to Promotional Ads
# Moved 00407.7a447442b07fa08de0b69e907ce3ca53 to Promotional Ads
# Moved 00410.b3134c2bf520f95f9b90d4aef4fdd683 to Promotional Ads
# Moved 00414.b2312673ca5358901c801eb44c00e310 to Promotional Ads
# Moved 00421.ca2fe949a956845a9ba81c649a7db6c0 to Promotional Ads
# Moved 00425.1434e0ab4e5235b64825b4c2a0999d76 to Promotional Ads
# Moved 00428.a7bbcb15affd49a93d516d5ed5700d66 to Promotional Ads
# Moved 00429.0061e48e64f9ce93ffae69bba9151357 to Promotional Ads
# Moved 00431.12b2043fed99f1202eb0677969d1a61e to Promotional Ads
# Done moving files.
